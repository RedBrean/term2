# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
filik = pd.read_csv("vivod.csv")
filik
plt.bar(filik["грань"], filik["так себе кубик"])
plt.figure()
plt.bar(filik["грань"], filik["зашибись кубик"])
plt.figure()
plt.bar(filik["грань"], filik["РОМА"])
# Out:
# <BarContainer object of 100 artists>

# %%
kiwi_coshelek = pd.read_csv("vivod_2.csv")
plt.bar(kiwi_coshelek["грань"], kiwi_coshelek["птичка"])
plt.figure()
plt.bar(kiwi_coshelek["грань"], kiwi_coshelek["томас шелби"])
# Out:
# <BarContainer object of 200 artists>
