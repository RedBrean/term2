# %% [markdown]
# # Квантовые ямы
# Выполнили Замятин Алексей и Дрязгов Владислав

# %% [markdown]
# ![](q_well_a581.png)

# %% [markdown]
# Первый образец квантовой ямы

# %% [markdown]
# ![](q_well_c262.png)

# %% [markdown]
# Второй образец квантовой ямы

# %% [markdown]
# ![](q_well_c263.png)

# %% [markdown]
# Третий образец квантовой ямы

# %% [markdown]
# ![](q_well_no_name.png)

# %% [markdown]
# Образец квантовой ямы без подписи

# %% [markdown]
# ![](q_wells.png)

# %% [markdown]
# Разные квантовые ямы

# %% [markdown]
# ![](q_well_a581_with_lower_intensity.png)

# %% [markdown]
# а581 с ослаблением мощности

# %% [markdown]
# ![](q_dot_q_dot.png)

# %% [markdown]
# Зелёная квантовая точка

# %% [markdown]
# ![](q_dot_q_dot_green.png)

# %% [markdown]
# Ещё одна зелёная квантовая точка

# %% [markdown]
# ![](q_dot_qdot_red.png)

# %% [markdown]
# Красная квантовая точка

# %% [markdown]
# ![](q_dot_qdot_kreplenie.png)

# %% [markdown]
# Крепление, испачканное жидкостью из красной квантовой точки

# %% [markdown]
# ![](q_dots.png)

# %% [markdown]
# Разные квантовые точки
