# %% [markdown]
# 1) Рассмотрите модель:
#
#    $$
#    f(x) = a x^b + c.
#    $$
#
#     Оцените параметры модели с помощью `curve_fit` и `minimize`, используя несколько стартовых точек. Сравните результаты и выберите наилучший фит.

# %%
import numpy as np
x = [1.        , 1.1025641 , 1.20512821, 1.30769231, 1.41025641,
        1.51282051, 1.61538462, 1.71794872, 1.82051282, 1.92307692,
        2.02564103, 2.12820513, 2.23076923, 2.33333333, 2.43589744,
        2.53846154, 2.64102564, 2.74358974, 2.84615385, 2.94871795,
        3.05128205, 3.15384615, 3.25641026, 3.35897436, 3.46153846,
        3.56410256, 3.66666667, 3.76923077, 3.87179487, 3.97435897,
        4.07692308, 4.17948718, 4.28205128, 4.38461538, 4.48717949,
        4.58974359, 4.69230769, 4.79487179, 4.8974359 , 5.        ]

y = [ 4.39628482,  4.44065528,  5.92401363,  6.54664358,  5.57062239,
         7.12106346,  7.28157063,  7.48051128,  7.09346301,  8.77714917,
         8.93568391,  8.05724366,  9.16968043,  8.67482988,  8.55187515,
         8.53554547, 10.00980363,  9.18712579,  9.09138498, 11.96267751,
        12.54336966, 12.59170702, 12.85923337, 13.67865326, 14.24043572,
        13.14969408, 14.73311347, 15.46741248, 14.96324553, 16.07283511,
        14.88546944, 16.05669812, 15.41200947, 17.04115781, 19.04734005,
        18.22765824, 18.42365723, 16.63515185, 19.56971083, 20.44601343]

# %% [markdown]
# 2) Рассмотрите систему
#
# $$
# \left\{\begin{array}{l}
# F_1(x, y)=x^2+y^2-1=0 \\
# F_2(x, y)=x^2-y=0
# \end{array}\right.
# $$
#
# Решите её сведением к поиску минимума функции $\Psi(x, y) = F_1^2(x, y) + F_2^2(x, y)$ равному 0 методом наискорейшего спуска.
#
# Постройте на квадрате $[-2; 2]\text{x}[-2; 2]$ области притяжения к корням (синим) и области, в которых сходимость идёт не к точке $\Psi=0$ (жёлтым). Будет ли в последних сходимость методом Ньютона?

# %% [markdown]
# 3) Рассмотрите СЛАУ размером 5x5, заданную, к примеру, матрицей с диагональным преобладанием. Используйте метод Якоби для нахождения решения с заданной точностью. Оцените число итераций, необходимое для достижения заданной точности. Постройте гистрограмму этого числа итераций на различных правых частях (случайно сгенерированных)
#
#
#    $$
#    \begin{pmatrix}
#    4 & 1 & 0 & 0 & 0 \\
#    1 & 4 & 1 & 0 & 0 \\
#    0 & 1 & 4 & 1 & 0 \\
#    0 & 0 & 1 & 4 & 1 \\
#    0 & 0 & 0 & 1 & 4
#    \end{pmatrix}
#    $$

# %% [markdown]
# 4) Рассмотрите матрицу:
#    $$
#    A=\begin{pmatrix}
#    2 & 17 & 2 \\
#    0 & 0 & 1 \\
#    -2 & i & 2
#    \end{pmatrix}.
#    $$
#    Сгенерируйте малые случайные возмущения элементов. Для каждой возмущённой матрицы найдите собственные числа и нанесите их на комплексную плоскость c параметром прозрачности (alpha=0.2). Оцените псевдоспектр матрицы.
